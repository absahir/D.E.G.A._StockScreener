# %%
import os
import time
import pandas as pd
import webbrowser
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob

# %%
yahoo.fin
pandas
requests.html
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-50a9943c2ab8> in <module>
# ----> 1 yahoo.fin
#       2 pandas
#       3 requests.html
#
# NameError: name 'yahoo' is not defined

# %%
from yahoo_fin.stock_info import *

# %%
# !pip install yahoo.fin

# %%
# !pip install requests_html
# Out:
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13489 sha256=a5e919b74f9f7b9345bff4ac080529dd6dcba18201dc23b809352ed1298d796c
#   Stored in directory: c:\users\louis\appdata\local\pip\cache\wheels\ed\f7\62\50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1277 sha256=92a7a9da6411ce00741af41e21f631af5e045441d2000988894359f3b1eb4fb5
#   Stored in directory: c:\users\louis\appdata\local\pip\cache\wheels\0a\9e\ba\20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24584 sha256=fc5cb5073bf7563f7b2a095da3e98e35dc8489584d36e72815903bf18b86c208
#   Stored in directory: c:\users\louis\appdata\local\pip\cache\wheels\9c\aa\cc\f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# Successfully built fake-useragent bs4 parse
# ...
#   Attempting uninstall: importlib-metadata
# ...

# %%
from yahoo_fin.stock_info import *

# %%
print(get_live_price("AAPL"))
# Out:
# 135.1300048828125

# %%
print(get_quote_table("AAPL"))
# Out:
# {'1y Target Est': 151.75, '52 Week Range': '53.15 - 145.09', 'Ask': '134.94 x 800', 'Avg. Volume': 103950088.0, 'Beta (5Y Monthly)': 1.27, 'Bid': '134.90 x 800', "Day's Range": '133.77 - 136.39', 'EPS (TTM)': 3.69, 'Earnings Date': 'Apr 28, 2021 - May 03, 2021', 'Ex-Dividend Date': 'Feb 05, 2021', 'Forward Dividend & Yield': '0.82 (0.61%)', 'Market Cap': '2.269T', 'Open': 135.9, 'PE Ratio (TTM)': 36.65, 'Previous Close': 135.39, 'Quote Price': 135.1300048828125, 'Volume': 64280029.0}

# %%
print(tickers_sp500())
# Out:
# ['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AES', 'AFL', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'ALL', 'ALLE', 'ALXN', 'AMAT', 'AMCR', 'AMD', 'AME', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANET', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APD', 'APH', 'APTV', 'ARE', 'ATO', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AZO', 'BA', 'BAC', 'BAX', 'BBY', 'BDX', 'BEN', 'BF.B', 'BIIB', 'BIO', 'BK', 'BKNG', 'BKR', 'BLK', 'BLL', 'BMY', 'BR', 'BRK.B', 'BSX', 'BWA', 'BXP', 'C', 'CAG', 'CAH', 'CARR', 'CAT', 'CB', 'CBOE', 'CBRE', 'CCI', 'CCL', 'CDNS', 'CDW', 'CE', 'CERN', 'CF', 'CFG', 'CHD', 'CHRW', 'CHTR', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COO', 'COP', 'COST', 'CPB', 'CPRT', 'CRM', 'CSCO', 'CSX', 'CTAS', 'CTLT', 'CTSH', 'CTVA', 'CTXS', 'CVS', 'CVX', 'D', 'DAL', 'DD', 'DE', 'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISCK', 'DISH', 'DLR', 'DLTR', 'DOV', 
# ...

# %%
print(get_analysts_info("AAPL"))
# Out:
# {'Earnings Estimate':   Earnings Estimate  Current Qtr. (Mar 2021)  Next Qtr. (Jun 2021)  \
# 0   No. of Analysts                    29.00                 27.00
# 1     Avg. Estimate                     0.98                  0.82
# 2      Low Estimate                     0.85                  0.70
# 3     High Estimate                     1.09                  0.98
# 4      Year Ago EPS                     0.64                  0.64
#
#    Current Year (2021)  Next Year (2022)
# 0                39.00             36.00
# 1                 4.45              4.69
# 2                 4.10              3.64
# 3                 4.89              5.50
# 4                 3.28              4.45  , 'Revenue Estimate':           Revenue Estimate Current Qtr. (Mar 2021) Next Qtr. (Jun 2021)  \
# 0          No. of Analysts                      26                   24
# 1            Avg. Estimate                  77.06B               68.87B
# ...

# %%
print(get_balance_sheet("AAPL"))
# Out:
# endDate                    2020-09-26    2019-09-28    2018-09-29  \
# Breakdown
# accountsPayable           42296000000   46236000000   55888000000
# cash                      38016000000   48844000000   25913000000
# commonStock               50779000000   45174000000   40201000000
# inventory                  4061000000    4106000000    3956000000
# longTermDebt              98667000000   91807000000   93735000000
# longTermInvestments      100887000000  105341000000  170799000000
# netReceivables            37445000000   45804000000   48995000000
# netTangibleAssets         65339000000   90488000000  107147000000
# otherAssets               33952000000   32978000000   22283000000
# otherCurrentAssets        11264000000   12352000000   12087000000
# otherCurrentLiab          47867000000   43242000000   39293000000
# otherLiab                 46108000000   50503000000   48914000000
# otherStockholderEquity     -406000000    -584000000   -3454000000
# ...

# %%
print(get_cash_flow("AAPL"))
# Out:
# endDate                                 2020-09-26   2019-09-28   2018-09-29  \
# Breakdown
# capitalExpenditures                    -7309000000 -10495000000 -13313000000
# changeInCash                          -10435000000  24311000000   5624000000
# changeToAccountReceivables              6917000000    245000000  -5322000000
# changeToInventory                       -127000000   -289000000    828000000
# changeToLiabilities                    -1981000000  -2548000000   9172000000
# changeToNetincome                       6517000000   5076000000 -27694000000
# changeToOperatingActivities              881000000   -896000000  30016000000
# depreciation                           11056000000  12547000000  10903000000
# dividendsPaid                         -14081000000 -14119000000 -13712000000
# investments                             5335000000  58093000000  30845000000
# issuanceOfStock                          880000000    781000000    669000000
# ...

# %%
print(get_day_gainers)
# Out:
# <function get_day_gainers at 0x000001AE6CD10948>

# %%
print(get_stats("AAPL"))
# Out:
#                                          Attribute         Value
# 0                                Beta (5Y Monthly)          1.27
# 1                                 52-Week Change 3        66.70%
# 2                          S&P500 52-Week Change 3        15.88%
# 3                                   52 Week High 3        145.09
# 4                                    52 Week Low 3         53.15
# 5                          50-Day Moving Average 3        133.76
# 6                         200-Day Moving Average 3        120.85
# 7                              Avg Vol (3 month) 3       103.95M
# 8                               Avg Vol (10 day) 3        82.53M
# 9                             Shares Outstanding 5        16.79B
# 10                                           Float        16.77B
# 11                            % Held by Insiders 1         0.07%
# 12                        % Held by Institutions 1        59.66%
# ...

# %%
print(get_earnings("AAPL"))
# Out:
# {'quarterly_results':    actual    date  estimate
# 0    0.64  1Q2020      0.56
# 1    0.64  2Q2020      0.51
# 2    0.73  3Q2020      0.70
# 3    1.68  4Q2020      1.41, 'yearly_revenue_earnings':    date     earnings       revenue
# 0  2017  48351000000  229234000000
# 1  2018  59531000000  265595000000
# 2  2019  55256000000  260174000000
# 3  2020  57411000000  274515000000, 'quarterly_revenue_earnings':      date     earnings       revenue
# 0  1Q2020  11249000000   58313000000
# 1  2Q2020  11253000000   59685000000
# 2  3Q2020  12673000000   64698000000
# 3  4Q2020  28755000000  111439000000}

# %%
print(get_quote_data("AAPL"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b0dc958cb2ba> in <module>
# ----> 1 print(get_quote_data("AAPL"))
#
# NameError: name 'get_quote_data' is not defined

# %%
# !pip install yahoo-finance
# Out:
# ...
#   Created wheel for yahoo-finance: filename=yahoo_finance-1.4.0-py3-none-any.whl size=7237 sha256=94264f59c87c26ac985604b873140902a578bf835a77faa4371a02a1a295ccab
#   Stored in directory: c:\users\louis\appdata\local\pip\cache\wheels\74\3c\6e\504622cec9991612b9e3945fe8b375fef727854b42eb333c91
# Successfully built yahoo-finance
# ...

# %%
from yahoo_finance import *
from yahoo_finance import Share

# %%
# !pip install pandas-datareader

# %%
# !pip install beautifulsoup4

# %%
# !pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1321 sha256=e8055a918d93904d8eeebf5d66a633657070899a6be6c4a9df23640de5ff5bf1
#   Stored in directory: c:\users\louis\appdata\local\pip\cache\wheels\46\ef\c3\157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# ...

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web

# %%
style.use('ggplot')

# %%
start = dt.datetime(2020,1,1)
end = dt.datetime(2021,2,11)
df = web.DataReader('AAPL','yahoo',start,end)
print(df.head())
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  74.333511
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.610840
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  74.197395
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.848442
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  75.036385

# %%
df.to_csv('AAPL.csv')

# %%
df = pd.read_csv('AAPL.csv', parse_dates=True, index_col=0)
df['100MA']= df['Adj Close'].rolling(window=100, min_periods=0).mean()
print(df.head())
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0
#
#             Adj Close      100MA
# Date
# 2020-01-02  74.333511  74.333511
# 2020-01-03  73.610840  73.972176
# 2020-01-06  74.197395  74.047249
# 2020-01-07  73.848442  73.997547
# 2020-01-08  75.036385  74.205315

# %%
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex= ax1)

ax1.plot(df.index, df['Adj Close'])
ax1.plot(df.index, df['100MA'])
ax2.bar(df.index, df['Volume'])

plt.show()
# Out:
# C:\Users\louis\anaconda3\envs\pyvizenv\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# !pip install --upgrade mplfinance

# %%
import mplfinance as mpf
#import matplotlib.dates as mdates

# %%
df_ohlc = df['Adj Close'].resample('10D').ohlc()
df_Volume = df['Volume'].resample('10D').sum()

# %%
df = pd.read_csv('AAPL.csv', parse_dates=True, index_col=0)
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex= ax1)
#plt.show

# %%
mpf.plot(df_ohlc)

# %%
mpf.plot(df_ohlc, type = 'candle')

# %%
mpf.plot(df_ohlc, type = 'line')

# %%
year = pd.read_csv('AAPL.csv',index_col=0,parse_dates=True)
year.index.name = 'Date'
mpf.plot(year,type='renko')

# %%
mpf.plot(year,type='pnf')

# %%
mpf.plot(df_ohlc,type='ohlc',mav=4)

# %%
mpf.plot(df_ohlc,type='candle',mav=(3,6,9))

# %%
mpf.plot(df,type='candle',mav=(3,6,9),volume=True)
